# %% [markdown]
# # Welcome to Your First Python Lab!
#
# ## What We'll Explore Together Today:
# - Part 0: Learn how to work with Jupyter Notebooks
# - Part 1: Discover primitives and variables - the building blocks of programming
# - Part 1.5: Master type casting - transforming data like a pro
# - Part 2: Perform basic operations using Python
# - Part 2.5: Play with strings using operators
# - Build more complex tools by combining what you learn
#
# Let's dive in and start coding!

# %% [markdown]
# ### Before you go further, if you are working locally, you can activate the virtual environment you created in lab 1.
#
# **1. To activate the virtual environment:**
#
# - **On Windows:**
# ```bash
# .venv\Scripts\activate
# ```
#
# - **On Mac/Linux/WSL:**
# ```bash
# source .venv/bin/activate
# ```
#
# You'll know it worked when you see `(.venv)` appear before your command prompt!
#
# **2. When you're done working, deactivate it:**
# ```bash
# deactivate
# ```
#
# ---
#
# **Awesome! Now let's start coding!**

# %%
# Run this cell by hitting Shift+Enter
# or clicking the "Play" button on the left side of this cell.

# !python --version
# Out:
# Python 3.13.15

# %% [markdown]
# #### P.S. This is called **Markdown** - it's like a superpower for making your code readable and beautiful!
# You'll use it to add comments, instructions, and make your notebooks look professional.

# %% [markdown]
# > **Pro Tip:** We've provided links to the official Python documentation in some places. These are great resources to explore when you want to dive deeper!
#
# > [Official Python Documentation](https://docs.python.org/3/)

# %% [markdown]
# ## Part 0: What is a Jupyter Notebook?

# %% [markdown]
# Think of a Jupyter Notebook as your digital lab notebook - like a scientist's journal, but for code! It lets you write and run code, see the output instantly, and write explanatory text all in one place. It's an amazing tool for learning, experimenting, and sharing your work.
#
# A notebook is made of **cells**. There are two main types we'll use:
#
# * **Code Cells**: This is where you write and run your Python code. It's your playground!
# * **Markdown Cells**: This is where you write formatted text, like headings, lists, and notes (you're reading one right now!).
#
# **To run a cell and move to the next one, press `Shift + Enter`.** Let's try it!

# %%
# This is a code cell!
# Lines starting with a '#' are comments - Python ignores them. They're notes for us coders!
# Run this cell by clicking on it and pressing Shift + Enter.

print("Hello, future Python programmers!")
# Out:
# Hello, future Python programmers!

# %% [markdown]
# **Great job!** Now let's learn some Markdown basics so you can make your notebooks look awesome:
#
# ---
#
# ### Headings
# ```
# # Heading 1 (for titles)
# ## Heading 2 (for main sections)
# ### Heading 3 (for sub-sections)
# ```
#
# ---
#
# ### Text Formatting
# You can make text *italic* by wrapping it in asterisks (`*italic*`) or **bold** by using double asterisks (`**bold**`).
#
# ---
#
# ### Lists
# You can create bulleted lists:
# * Item 1
# * Item 2
#     * A sub-item (use 4 spaces before the asterisk!)
#
# Or numbered lists:
# 1. First step
# 2. Second step
# 3. Third step
#
# ---
#
# ### **Your Turn!**
# **Double-click on this cell to edit it.** Below this line, add a Heading 3 with your name and a bulleted list of two things you hope to learn in this course. When you're done, run the cell (`Shift + Enter`) to see your formatted text!
#
# ---
# *Add your response below this line:*
# ### Arshit
# * I want to learn and master python
# * I want to be able to use GitHub properly and master the terminal.

# %% [markdown]
# ---
#
# ## Part 1: Variables and Primitives - The Building Blocks
#
# Now we're getting to the fun part! Let's learn how computers store and use information.

# %% [markdown]
# ### What are Variables?
#
# Think of **variables** as labeled boxes where you can store information. Just like you might label a box "School Supplies" or "Gaming Stuff", you give variables names to remember what's inside them.
#
# #### The Rules for Naming Variables:
# * **Case sensitive** - `age` and `Age` are different variables!
# * **Must start with a letter or underscore** - not a number (so `1st_place` won't work, but `first_place` will!)
# * **Can only contain letters, numbers, and underscores** (A-Z, a-z, 0-9, and `_`)
# * **Multi-word names should use underscores** - like `student_name` or `favorite_color`
# * **Don't use [Python keywords](https://docs.python.org/3/reference/lexical_analysis.html#keywords)** - words like `print`, `for`, `if` are reserved!
# * **Declaring the same variable again will overwrite it** - the old value disappears!
#
# #### How to Create a Variable:
# * Use `=` to assign a value to a variable
# * Example: `age = 15` will store the number `15` in a variable called `age`
#
# #### **Your Challenge:**
# In the cell below, try to **break these rules on purpose** and see what error messages Python gives you. This is how you learn what NOT to do!

# %%
# Try breaking the rules here and see what happens!
# Example: Try creating a variable that starts with a number
# or has spaces in its name
1age = 100
age arshit = 18
# Out:
#   File "/tmp/ipykernel_1541/1787083256.py", line 4
#     1age = 100
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ---
#
# ### Understanding Primitives (Data Types)
#
# **Primitives** are the basic types of data Python can work with. Think of them as different kinds of containers - one for numbers, one for text, one for true/false values, etc.
#
# #### There are 4 main primitive types in Python.
# **Can you name them?** Fill in the blanks below inside the quotes:

# %%
primitive_1 = "int"
primitive_2 = "float"
primitive_3 = "bool"
primitive_4 = "str"

# %%
# Let's create some variables with different types
a = 3
b = 'Someone is running this cell'
c = 56.2
d = True

## Your task: Find the type of primitive assigned to each variable
## Use the cells below to check your answers!

# %%
## Use type() function to get the answers!
## Example: type(a) will tell you what type 'a' is
## Run the cells below one by one to see the results

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
type(c)
# Out:
# float

# %%
type(d)
# Out:
# bool

# %%
# Now let's create your own variables!
# Create a variable called 'course_name' and store the actual course name in it
course_name = 'coding cafe'

# Create a variable to store the number of students in this class
number_of_students = 50

# Now, let's see what's inside our variables using the print() function
print(course_name)
print(number_of_students)

# Awesome! You just created and displayed your first variables!
# Out:
# coding cafe
# 50

# %% [markdown]
# ---
#
# ### Spot the Errors!
#
# Below are some variable names. Some follow the rules, and some break them!
#
# **Good variable names:** `student_name`, `age`, `user_id_01`, `_temporary_var`
#
# **Bad variable names:** `1st_place`, `student-name`, `my name`
#
# #### Your Turn:
# Can you figure out why the bad ones won't work? Test them in the cell below and see what error messages Python gives you!

# %%
# Test the variable names here and see what errors are thrown!
# Try assigning values to each of the "bad" variable names
# Example: 1st_place = "Gold Medal"
my name = 'arshit'
# Out:
#   File "/tmp/ipykernel_1541/2205219638.py", line 4
#     my name = 'arshit'
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
#
# ## Part 1.5: Type Casting - Transforming Data!

# %% [markdown]
# **Great work so far!** Now let's learn something super useful: **type casting**.
#
# ### What is Type Casting?
#
# Type casting is like being a data transformer! Sometimes Python gives you data in one form (like a string), but you need it in another form (like a number). Type casting lets you convert between different data types.
#
# #### Why Do We Need This?
#
# Imagine you ask someone their age, and they say "16". To Python, that's just text (a string)! If you want to do math with it (like calculating birth year), you need to convert it to a number first.
#
# #### The Main Casting Functions:
#
# * `int()` - Converts to an integer (whole number)
# * `float()` - Converts to a floating-point number (decimal)
# * `str()` - Converts to a string (text)
# * `bool()` - Converts to a boolean (True/False)
#
# Let's see them in action!

# %%
# Converting strings to numbers
age_text = "16"
print("This is a string:", age_text)
print("Type:", type(age_text))

age_number = int(age_text)  # Convert string to integer
print("\nNow it's a number:", age_number)
print("Type:", type(age_number))

# Now we can do math with it!
birth_year = 2025 - age_number
print("You were born around:", birth_year)
# Out:
# This is a string: 16
# Type: <class 'str'>
#
# Now it's a number: 16
# Type: <class 'int'>
# You were born around: 2009

# %%
# Converting numbers to strings
score = 95
lives = 3

# Try to combine them - this will cause an error! (Try uncommenting the line below)
# message = "You scored " + score + " points with " + lives + " lives left"

# The right way - convert numbers to strings first:
message = "You scored " + str(score) + " points with " + str(lives) + " lives left"
print(message)
# Out:
# You scored 95 points with 3 lives left

# %%
# Converting between int and float
whole_number = 42
decimal_number = 3.14159

# int to float
print("Integer to float:", float(whole_number))  # Output: 42.0

# float to int (WARNING: This removes the decimal part!)
print("Float to integer:", int(decimal_number))  # Output: 3

# Be careful - you lose the decimal part!
price = 19.99
print("Price as integer:", int(price))  # Output: 19 (loses the .99!)
# Out:
# Integer to float: 42.0
# Float to integer: 3
# Price as integer: 19

# %% [markdown]
# #### The `input()` Problem
#
# Here's something **really important**: When you use `input()` to get data from a user, Python **always** treats it as a string - even if they type a number!
#
# This is one of the most common beginner mistakes. Let's see why type casting is crucial:

# %%
# THE WRONG WAY (don't do this!)
# Uncomment these lines to see the error:
 num1 = input("Enter first number: ")
 num2 = input("Enter second number: ")
 result = num1 + num2  # This will concatenate strings, not add numbers!
 print("Result:", result)  # If you enter 5 and 3, you get "53" instead of 8!

print("If you entered 5 and 3, you'd get '53' instead of 8!")
# Out:
#   File "/tmp/ipykernel_1541/405702514.py", line 3
#     num1 = input("Enter first number: ")
#     ^
# IndentationError: unexpected indent

# %%
# THE RIGHT WAY (do this instead!)
num1 = int(input("Enter first number: "))  # Convert to int immediately!
num2 = int(input("Enter second number: "))
result = num1 + num2  # Now this actually adds the numbers
print("Result:", result)  # 5 + 3 = 8
# Out:
# Enter first number: 20
# Enter second number: 30
# Result: 50

# %% [markdown]
# #### Your Turn: Type Casting Practice!
#
# Try these exercises to master type casting:

# %%
# Exercise 1: Ask the user for their age and calculate their birth year
age = int(input("Enter your age : "))  # Use input() and convert to int
current_year = 2026
birth_year = current_year - age  # Calculate birth year
print("You were born around:", birth_year)
# Out:
# Enter your age : 18
# You were born around: 2008

# %%
# Exercise 2: Create a simple calculator
# Ask for two numbers and add them (make sure to convert to float for decimals!)
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))
sum_result = num1 + num2
print("The sum is:", sum_result)
# Out:
# Enter first number : 39
# Enter second number : 1
# The sum is: 40

# %% [markdown]
# #### Today's Checkpoint:

# %%
# Exercise 3: Mix it up!
# Get a number from user, multiply it by 10, then convert the result to a string
number = int(input("Enter a number : "))  # Get input and convert to int
result = number * 10  # Multiply by 10
result_text = str(result)  # Convert to string
print("Your number times 10 is: " + result_text)
# Out:
# Enter a number : 60
# Your number times 10 is: 600

# %% [markdown]
# ---
#
# ## Part 2: Basic Operations - Let's Do Some Math!

# %% [markdown]
# Now that you understand variables and types, let's make them do something useful! Python can be your super-powered calculator.
#
# ### Mathematical Operations:
# * `+` Addition
# * `-` Subtraction
# * `*` Multiplication
# * `/` Division
# * `**` Exponentiation (power)
# * `//` Floor division (division that rounds down)
# * `%` Modulo (remainder after division)
#
# Let's explore what happens when you use these with different data types!

# %% [markdown]
# ### Experiment Time!
#
# **Try different operations with different types and values. See what works and what doesn't!**
#
# Some will work in surprising ways, others will give errors.

# %%
# A Quick Reminder About Comments:
# You've probably noticed that our instructions don't get printed,
# and they don't cause errors either. These are COMMENTS!
# Comments are not executed - they're notes for humans.
# They help you remember what your code does and help others understand it.

# You can toggle comments with "Ctrl + /" or by adding a '#' before the line.
# Try it on the line below!
print("This line will run")
# Out:
# This line will run

# %%
# Try these operations and see what happens!
# For the lines that don't work, turn them into comments (add # at the start)
a = 12 + 3  # Adding numbers - this works!
b = "This is" + " too lengthy"  # Adding strings - does this work?
# c = "This is" - "does not work"  # Subtracting strings - what happens?
# d = "Even this" // "does not"  # Floor division on strings?
e = "Maybe this does" + ("?" * 3)  # String multiplication - does this work?

# Print them to see the results (comment out the ones that error!)
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# 15
# This is too lengthy
# 56.2
# True
# Maybe this does???

# %% [markdown]
# ---
#
# ### [Comparison Operators](https://docs.python.org/3/library/stdtypes.html#comparisons) - Making Decisions
#
# Comparison operators let you compare values. They always return `True` or `False` (boolean values).
#
# Think of them like asking questions: "Is this bigger than that?" or "Are these equal?"
#
# ### The Comparison Operators:
# * `>` Greater than
# * `<` Less than
# * `>=` Greater than or equal to
# * `<=` Less than or equal to
# * `==` Equal to (**Note:** Use `==` for checking equality, not `=` which is for assignment!)
# * `!=` Not equal to
#
# There are two more (`is` and `is not`), but we'll save those for later!
#
# ### Try Them Out:
# Experiment with different primitive types and see what comparisons make sense!

# %%
# Try comparison operators here!
# Examples:
print(10 > 5)  # Is 10 greater than 5? True!
print(3 == 3)  # Is 3 equal to 3? True!
print("apple" == "Apple")  # Are these equal? (Remember: case sensitive!)

# Your turn - try more comparisons:
# Compare your age to 18
# Compare two strings
# Try comparing different types - what happens?
age = 18
print(age == 18)
print('arshit' == 'smart')
print(23 == 23.00)
# Out:
# True
# True
# False
# True
# False
# True

# %% [markdown]
# ---
#
# ## Part 2.5: Strings - Playing with Operators
#
# Strings are just another data type - and just like numbers, they have their own operators! Some operators you already know behave a little differently when you use them on text instead of numbers.

# %% [markdown]
# ### String Operators
#
# * `+` does **concatenation** (joining strings together)
# * `*` does **repetition** (repeating a string multiple times)
# * `==` and `!=` check if two strings are **equal** or **not equal** (remember, this is case sensitive!)
#
# Note: strings do **not** support `-`, `/`, `//`, `%`, or `**` - those will throw an error!

# %%
# Concatenation with +
greeting = "Hello" + ", " + "Coding Cafe" + "!"
print(greeting)

# Repetition with *
border = "-" * 20
print(border)
# Out:
# Hello, Coding Cafe!
# --------------------

# %%
# Comparison with == and !=
print("apple" == "apple")   # True
print("apple" == "Apple")   # False - case sensitive!
print("apple" != "banana")  # True
# Out:
# True
# False
# True

# %% [markdown]
# ### Your Turn: String Operators Practice!

# %%
# Exercise A: Use + to build a full name from a first and last name
first_name = "Priya"
last_name = "Kapoor"
full_name = first_name + ' ' + last_name  # Combine first_name and last_name with a space in between
print(full_name)
# Out:
# Priya Kapoor

# %%
# Exercise B: Use * to print a line of 10 equal signs, e.g. "=========="
line = '=' * 10
print(line)

# %%
# Exercise C: Ask the user for a password twice and check if the two entries match
password1 = input('Enter a password : ')  # Ask with input()
password2 = input('Enter the password again : ')  # Ask with input()
passwords_match = password1 == password2  # Use == to compare
print("Passwords match:", passwords_match)
# Out:
# Enter a password : arshit
# Enter the password again : arshit
# Passwords match: True

# %% [markdown]
# ---
#
# ### Getting User Input with `input()` and `print()`
#
# Now let's make our programs interactive! We can ask users for information and respond to them.

# %%
# input() gets information from the user
# IMPORTANT: input() always returns a STRING, even if the user types a number!

# Syntax: variable = input("Your prompt message")
name = input("Enter your name: ")
print("Hello, " + name + "!")
print("Nice to meet you!")

# Try running this cell and type your name when prompted, then hit Enter!
# Out:
# Enter your name: Arshit
# Hello, Arshit!
# Nice to meet you!

# %%
# Your turn! Create a program that asks for two city names
# and prints them in a sentence like "City1 is far from City2"

city1 = input('Tell me a city : ')  # Ask for first city
city2 = input('Tell me another city : ')  # Ask for second city
print('The city of ' + city1 + ' has been there since so long and it is actually very far from the city of ' + city2)  # Create and print your sentence

# Bonus: Make it more interesting! Add more text to make it sound like a story!
# Out:
# Tell me a city : Mumbai
# Tell me another city : Kalyan
# The city of Mumbai has been there since so long and it is actually very far from the city of Kalyan

# %%
# Write a program that asks for the user to enter their favorite band's name from the
# intra music competition and their favorite song by that band, then prints a message like:
# "Your favorite band was [Band] and your favorite song by them was [Song]
favBand = input('Enter your favorite band from the intra music competition ')
favSong = input('Enter your favorite song by that band ')

# Anything except Prof Raghav and Like A Stone is not accepted lol

print('Your fav band was ' +favBand+ ' and your fav song from that band was '+favSong)
# Out:
# Enter your favorite band from the intra music competition Prof Raghav
# Enter your favorite song by that band Like A Stone
# Your fav band was Prof Raghav and your fav song from that band was Like A Stone
