# %% [markdown]
# # Lab 3
#
# Welcome to `lab 3`! In this session, we'll explore -
#
# * **Conditionals & Branching**:
#     * if/elif/else
#     * Boolean logic
#     * indentation-as-syntax
#     * decision-making problems
#
# * **Loops & Iteration**
#     * for-in
#     * while
#     * range
#     * loop patterns (accumulate, search, count)
#     * tracebacks

# %% [markdown]
# ### Conditional Statements:
#
# Imagine you're a sports commentator. If a batsman scores 100 runs or more, you shout that they've made a century. Else if they score 50 or more, you announce a solid half-century. Else, you politely state they did neither.
#
# That’s exactly how conditional statements work in Python! They let your code make decisions on the fly based on what's happening at that exact moment.
#
# The main keywords for this are:
#
# `if`: The main bouncer at the club. "If this condition is true, come on in!"
#
# `elif`: The backup bouncer. "Okay, you didn't meet the first rule, but if you meet this rule, you can enter."
#
# `else`: The safety net. "If all else fails, just do this."
#
# Let's look at the cricket example in code:

# %%
runs = int(input("How many runs did the batsman score? "))

if runs >= 100:
    print("Batsman scored a century! ")
elif runs >= 50:
    print("Batsman scored a fifty! ")
else:
    print("Batsman has neither scored a century nor fifty. Better luck next time!")

# %% [markdown]
# Fun Fact 🤓: You can stack as many `elif` blocks as you want! If you're calculating a store discount, you might check if sales >= 30000, then elif sales >= 20000, then elif sales >= 10000, all the way down to a default `else`!
#
# The logic used in conditional statements (`True`/`False`) is called Boolean logic.

# %% [markdown]
# ## PUZZLE 1
#
#
# 🛸 Challenge : **The Intergalactic Toll Booth `(if / elif / else)`**
#
# The Scenario:
# You work the graveyard shift at a toll booth floating somewhere near Jupiter. You have to charge alien spaceships based on how many glowing tractor beams they have.
#
# If they have 5 or more beams, they are classified as a *"Mega-Cruiser."*
#
# If they have 2 or more beams, they are a *"Standard UFO."*
#
# If they have fewer than 2, they are just a *"Space Scooter."*
#
# The Task:
#
# Ask the alien driver for their beam count. Use an `if / elif / else` chain to print out exactly what kind of ship they are driving and clear them for passage!

# %%
beam_count = int(input("How many tractor beams does your ship have? "))

if beam_count >= 5:
    print("Mega-Cruiser cleared for passage!")
elif beam_count >= 2:
    print("Standard UFO cleared for passage!")
else:
    print("Space Scooter cleared for passage!")

# %% [markdown]
#   ## Boolean Operators: The Logic Connectors 🔗
#
# Boolean operators (`and`, `or`, `not`) are the glue that lets you combine multiple conditions. They only ever deal in absolutes: `True` or `False`.
#
# ### The `and` Operator
# Both conditions must be `True`.
# **Analogy:** To launch a rocket, you need `fuel_is_full` AND `weather_is_clear`. If you are missing fuel or there's a storm, the launch is a no-go[cite: 1]. Both must be true!
#
# ### The `or` Operator
# Only **one** condition needs to be `True`.
# **Analogy:** To get a museum discount, you can be an `is_student` OR an `is_senior_citizen`. You don't need to be both; just one gets you the deal!
#
# ### The `not` Operator
# This is the "reverse" button—it simply flips the value. It turns `True` into `False`, and `False` into `True`.
# **Analogy:** If your condition is `not raining`, that just means it's a clear day. `not tired` means you are awake!
#
# Pro-Tip: The Order of Logic 🤓
# If you combine these, Python reads them in a specific order: $not$ is evaluated first, then $and$, and finally $or$. You can always use parentheses () to force a different order, just like in math!

# %% [markdown]
# ### PUZZLE 2 : Conditionals, Boolean Logic & Ternary Operators
#
# #### The Snobby Dragon’s Snack Evaluator (Boolean Logic)
#
# A dragon is deciding whether to eat a wandering knight. The dragon has very specific dietary requirements: they only eat knights who are `is_crispy` AND `not wearing_garlic`. However, if the knight is holding a `tasty_pie`, the dragon will ignore all rules and eat them anyway.
#
# * Ask the user for three `True`/`False` inputs for these conditions.
# * Use a single `if` statement combining `and`, `or`, and `not` operators to evaluate the meal.
# * If the conditions are met, print `"Chomp! Delicious."`
# * If they aren't, print `"Ew, no thanks. You may pass."`

# %%
is_crispy = input("Is the knight crispy (True/False)? ").strip().lower() == "true"
wearing_garlic = input("Is the knight wearing garlic (True/False)? ").strip().lower() == "true"
tasty_pie = input("Is the knight holding a tasty pie (True/False)? ").strip().lower() == "true"

if (is_crispy and not wearing_garlic) or tasty_pie:
    print("Chomp! Delicious.")
else:
    print("Ew, no thanks. You may pass.")

# %% [markdown]
# ### 📐 The Triangle Tester CHALLENGE
#
# Write a program that asks the user to input the 3 sides of a triangle[cite: 2]. Using your new `if`/`elif`/`else` powers, tell the user if their triangle is:
#
# * **Equilateral** (all sides equal)
# * **Isosceles** (exactly two sides equal)
# * **Scalene** (no sides equal)

# %%
side_1 = float(input("Enter the first side: "))
side_2 = float(input("Enter the second side: "))
side_3 = float(input("Enter the third side: "))

if side_1 == side_2 == side_3:
    print("Equilateral")
elif side_1 == side_2 or side_2 == side_3 or side_1 == side_3:
    print("Isosceles")
else:
    print("Scalene")

# %% [markdown]
# ## Checkpoint 1 🚧
#
# ### The Secret Agent Alien Escape Pod 🚀
#
# You are the chief engineer designing the emergency escape pod for a high-stakes space station. The escape pod's automated hatch will **ONLY** launch if all security parameters are met!
#
# ### The Launch Rules:
# 1. The passenger must be an **authorized agent** (`is_agent = True`).
# 2. The passenger's weight must be **under 120 kg** (to avoid overloading the thrusters).
# 3. **Emergency Override:** If the space station's core is exploding (`core_exploding = True`), the pod ignores the weight restriction and launches for *any* authorized agent!
# 4. **Disqualification:** Regardless of everything else, if the alien passenger is carrying a `prohibited_weapon = True`, the hatch locks permanently!
#
# ### Your Task:
# * Ask the user for inputs representing these 4 conditions:
#   * `is_agent` (`yes`/`no`)
#   * `passenger_weight` (a number)
#   * `core_exploding` (`yes`/`no`)
#   * `prohibited_weapon` (`yes`/`no`)
# * Write a single, elegant `if/elif/else` or compound Boolean statement to test if the pod can launch.
# * If they can launch, print: `"HATCH UNLOCKED! Ejecting escape pod! "`
# * If they are disqualified by a weapon, print: `"SECURITY ALERT! Prohibited weapon detected. Hatch locked! "`
# * Otherwise, print: `"Launch denied! Safety parameters not met. "`

# %%
is_agent = input("Is the passenger an authorized agent (yes/no)? ").strip().lower() == "yes"
passenger_weight = float(input("Passenger weight in kg: "))
core_exploding = input("Is the core exploding (yes/no)? ").strip().lower() == "yes"
prohibited_weapon = input("Is the passenger carrying a prohibited weapon (yes/no)? ").strip().lower() == "yes"

if prohibited_weapon:
    print("SECURITY ALERT! Prohibited weapon detected. Hatch locked!")
elif is_agent and (passenger_weight < 120 or core_exploding):
    print("HATCH UNLOCKED! Ejecting escape pod!")
else:
    print("Launch denied! Safety parameters not met.")

# %% [markdown]
# ## Repetition & Pseudocode: The Infinite Dosa Machine 🥞
# We write code because humans get bored, and computers don't. Imagine you are tasked with making dosas. Doing it once is fun. Doing it 500 times is a nightmare.
#
# Before we write code, we write pseudocode : a plain-English map of what our code should do. If we want to make exactly 6 dosas, we need to maintain a count.
#
# It looks a little something like this:

# %% [markdown]
# ![image.png](attachment:e2c950ea-c32e-4b35-b698-2c23fbc314f8.png)

# %% [markdown]
# Notice how the flow jumps back up to **step C?** That's a loop! In Python, we don't use arrows; we use `while` and `for` loops.

# %% [markdown]
# ## The `while` Loop & The Great Escape (`break`) 🏃‍♂️💨
# A `while` loop is a conditional loop. It keeps repeating a block of code as long as a certain condition is `True`. But what if you need to bail out early because something went wrong?
#
# Enter the `break` statement. It’s the emergency exit. If a `break` is triggered, Python drops whatever it's doing and immediately leaves the loop.
#
# Imagine a program that asks for two numbers and divides them. If the user tries to divide by zero (which breaks the universe), we need to abort!

# %%
while True:
    numerator = float(input("Enter the numerator: "))
    denominator = float(input("Enter the denominator: "))

    if denominator == 0:
        print("Cannot divide by zero. Program stopped.")
        break

    print("Result:", numerator / denominator)
    break

# %% [markdown]
# ## PUZZLE 3
# ### 🎮 Mini-Game : Guess the Number
#
# Python generates a secret number randomly in the range 10 to 50. You are given five chances to guess the number.
#
# * Use a `for` or `while` loop to give the user up to 5 attempts.
# * If your guess matches the secret number, print `"You win!"` and use a `break` statement to terminate the loop early without completing all five iterations.
# * If you cannot guess the number in five attempts, print `"You lose!"`.

# %%
import random

# This generates a random number between 10 and 49 (inclusive)
secret_number = random.randint(10, 49)

print("I'm thinking of a number between 10 and 50. You have 5 attempts!")

for attempt in range(1, 6):
    guess = int(input(f"Attempt {attempt}: "))
    if guess == secret_number:
        print("You win!")
        break
else:
    print("You lose!")

# %% [markdown]
# ## The `for` Loop & The Art of Skipping (`continue`) 🦘
#
# While `while` loops run until a condition changes, `for` loops are designed to run a specific number of times. They are perfect for counting!
#
# But what if you are counting, and you just want to skip one specific iteration without destroying the whole loop? That's where `continue` comes in.
#
# If `break` flips the dinner table and leaves the room, `continue` just skips the broccoli on its plate and moves on to the next bite.
#
# Let's look at a loop that prints numbers from 1 to 10, but handles multiples of 3 very differently depending on the keyword used:

# %%
#scenario A
for i in range(1, 11):
    if i % 3 == 0:
        break  # The loop DIES the moment i becomes 3. 
    else:
        print(i)
# Output: 1, 2. (That's it. We went home.)

# %%
#scenario B
for i in range(1, 11):
    if i % 3 == 0:
        continue  # Skips 3, 6, and 9, but keeps going!
    else:
        print(i)
# Output: 1, 2, 4, 5, 7, 8, 10

# %% [markdown]
# Pro-Tip: While `continue` is a cool jump trick, try not to overuse it! Sometimes simply writing a clean `if/else` block is much easier for humans to read.

# %% [markdown]
# ## PUZZLE 4
#
# ### 🤖 The Picky Robot
#
# We have a tiny robot that hops along a number line from 1 to 10. However, this robot has a weird glitch: it absolutely refuses to step on any number that is a multiple of 3!
#
# * Write a `for` loop using `range(1, 11)`.
# * Inside the loop, check if the current number is divisible by 3 using the modulo operator `%`.
# * If it is divisible by 3, use the `continue` statement to skip to the next loop iteration.
# * Otherwise, print `"Robot hops to tile {number}"`.

# %%
for number in range(1, 11):
    if number % 3 == 0:
        continue
    print(f"Robot hops to tile {number}")

# %% [markdown]
# ## Checkpoint 2 🚧
#
# ### 👻 The Dramatic Ghost's Diary (Looping Through Strings)
#
# A ghost left a diary, but they are incredibly dramatic and drag out all their words (e.g., `"WaaaAAaake meeeeee uuup!"`). We need to find out exactly how dramatic they are by counting the vowels!
#
# * Ask the user to enter a spooky ghost quote.
# * Write a `for` loop that iterates through every character in the string.
# * Check if the character is in `"aeiouAEIOU"`.
# * Keep a running count of the vowels.
# * If the total vowel count is over 10, print `"Whoa, dial down the drama, Casper."` Otherwise, print the final vowel count!

# %%
ghost_quote = input("Enter a spooky ghost quote: " )
vowel_count = 0

for character in ghost_quote:
    if character in "aeiouAEIOU":
        vowel_count += 1

if vowel_count > 10:
    print("Whoa, dial down the drama, Casper.")
else:
    print("Vowel count:", vowel_count)

# %% [markdown]
# ## Grand Lab Checkpoint 🏆
#
# ### The Goblin Alchemy Workshop 🧪
#
# #### This is fairly extensive. Read and solve each piece on by one to get the solution.
#
# You have been hired as an assistant at a chaotic goblin alchemy workshop! Your job is to run the automated cauldron station, brew mysterious potions, and keep the explosive ingredients under control.
#
# ---
#
# ### 📋 Workshop Regulations:
#
# 1. **VIP Goblin Verification (Conditionals & Boolean Logic):**
#    * Ask the user if the goblin is a `"master"` alchemist (`yes`/`no`) and how many `shiny_coins` they are carrying.
#    * If the goblin is a `"master"` **or** has `shiny_coins` greater than `50`, print `"Welcome, Master Goblin! Brewing the Royal Elixir."`
#    * Otherwise, print `"Welcome, Apprentice! Brewing standard Swamp Water."`
#
# 2. **The Cauldron Filling Loop (`while` & Accumulator):**
#    * The cauldron starts at `0` liters.
#    * Use a `while` loop to continuously add potion liquid to the cauldron by asking: `"How many liters of potion liquid to add?"`
#    * Keep an accumulator tracking `total_liquid`.
#    * **Emergency Break:** If the user inputs a negative number (e.g., `-1`), print `"CRITICAL ERROR! Corrosive acid detected! Shutting down cauldron."` and **`break`** out of the loop immediately!
#    * The loop stops when `total_liquid` reaches or exceeds `100` liters.
#
# 3. **Labeling Potion Vials (`for`, `range`, & `continue`):**
#    * Once the potion is brewed, loop through 5 potion vials numbered `1` through `5` using `range()`.
#    * **The Curse Glitch:** Goblins *refuse* to touch Vial #3 because it is cursed. Use a `continue` statement to skip labeling vial #3!
#    * For all other vials, print `"Poured potion into Vial #", vial`.
#
# 4. **Ternary Explosion Check:**
#    * At the end of the shift, ask the user if the cauldron temperature is `"hot"` or `"safe"`.
#    * Use a **one-line ternary statement** to assign `status_report`:
#      `"Workshop exploded"` if temperature is `"hot"`, else `"Brewing success"`.
#    * Print `"Shift finished! Final status: ", status_report`

# %%
is_master = input("Is the goblin a master alchemist (yes/no)? " ).strip().lower() == "yes"
shiny_coins = int(input("How many shiny coins does the goblin have? "))

if is_master or shiny_coins > 50:
    print("Welcome, Master Goblin! Brewing the Royal Elixir.")
else:
    print("Welcome, Apprentice! Brewing standard Swamp Water.")

total_liquid = 0
while total_liquid < 100:
    liquid_to_add = float(input("How many liters of potion liquid to add? "))
    if liquid_to_add < 0:
        print("CRITICAL ERROR! Corrosive acid detected! Shutting down cauldron.")
        break
    total_liquid += liquid_to_add

for vial in range(1, 6):
    if vial == 3:
        continue
    print("Poured potion into Vial #", vial)

temperature = input("Is the cauldron temperature hot or safe? " ).strip().lower()
status_report = "Workshop exploded" if temperature == "hot" else "Brewing success"
print("Shift finished! Final status: ", status_report)
